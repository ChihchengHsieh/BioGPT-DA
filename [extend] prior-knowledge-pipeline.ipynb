# %%
from aug.features import *
import warnings
warnings.filterwarnings("ignore")

# %%
def get_questions_by_lesion(lesion: str):
    questions = [
        # f"What is {lesion}?", # don't need the first one for extending features.
        f"What are the symptoms associated with {lesion}?",
        f"What can cause {lesion}?",        
        f"What are the patient’s symptoms that are relevant for {lesion}?",
        f"What are the relevant clinical signs for the etiological diagnosis of {lesion}?",
        f"What are the relevant laboratory data for the etiological diagnosis of {lesion}?",
        f"What are the relevant clinical characteristics for the etiological diagnosis of {lesion}",
        f"What are the patient’s personal relevant history for the etiological diagnosis of {lesion}",
    ]
    return questions

# %%
lesion = "atelectasis"
## adding prior knowledge from 8 questions.
questions = get_questions_by_lesion(lesion)
responses = LLM_get_responses(questions, llm=QuestionLLM.Mistral) # let's try to get the responses from other LLMs to predict the keywords.
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
# identified_keywords = {
#     "boolean": [
#         "blockage of the airways",
#         "chest pain",
#         "chronic obstructive pulmonary disease (copd)",
#         "collapse or closure of a lung",
#         "coughing",
#         "foreign object",
#         "pneumonia",
#         "prolonged bed rest",
#         "rapid breathing",
#         "reduced or absent gas exchange",
#         "shortness of breath",
#     ],
#     "numerical": ["oxygen saturation (%)"],  # 'low oxygen levels',
#     # 'lung diseases',
#     # 'mucus',
#     # 'pneumonia',
#     # 'surgery',
#     # 'tumor'
# }

# %%
# identified_keywords = {  # networkx
#     "boolean": [
#         "abnormal chest x-ray findings",
#         "abnormal lung sounds",
#         "collapsed lung tissue" "bluish skin color",
#         "chest pain",
#         "coughing",
#         "coughing up blood",
#         "crackling sounds in the lungs",
#         "decreased appetite",
#         "decreased breath sounds",
#         "decreased oxygen saturation",
#         "difficulty breathing",
#         "difficulty speaking",
#         "dyspnea",
#         "fatigue",
#         "history of being on mechanical ventilation",
#         "history of chest trauma or injury",
#         "history of chronic obstructive pulmonary disease (copd)",
#         "history of lung cancer",
#         "history of lung diseases",
#         "history of neuromuscular disorders",
#         "history of prolonged bed rest or immobility",
#         "history of recent surgery",
#         "history of respiratory infections",
#         "history of smoking for 20 years",
#         "advanced age",
#         "low oxygen levels",
#         "obesity",
#         "fungi in sputum culture",
#         "presence of bacteria",
#         "rapid breathing",
#         "shortness of breath",
#         "smoking",
#         "tachypnea",
#         "underlying lung diseases",
#         "viruses",
#         "wheezing",
#         "white-out appearance in the affected area of the lung",
#     ],
#     "numerical": ["levels of oxygen and carbon dioxide in the blood"],
#     #  'amount of air that can be inhaled and exhaled',
#     #  'use of accessory muscles',
#     #  'viruses',
# }

# %%
identified_keywords = {  # Neo4jVector
    "boolean": [
        "anesthesia",
        "asthma",
        "asymptomatic",
        "breathing difficulty",
        "chest pain",
        "chronic obstructive pulmonary disease",
        "cough",
        "cyanosis",
        "fever",
        "pleural effusion",
        "pulmonary tuberculosis",
        "small volume linear shadows",
        "smoking"
        # Response: Risk factors for atelectasis include certain types of surgery, muscle relaxation, obesity, high oxygen, and lower lung segments.',
        # "high oxygen",  # A cause, not a symptom. Has the patient been the situation with high oxygen. # remove this for not causing confusion to LLMs.

    ],

    "numerical": [
        "heart rate (per minute)",  # "increased heart rate",
        "oxygen saturation (%)",  # "low oxygen saturation",
    ],
    # 'old age', # already provided in the report.
}

# %%
import pandas as pd
df = pd.read_csv('./spreadsheets/reflacx_clinical.csv')
sample_df = df.iloc[:50]

# %%
results = []
all_res = []
all_prompt = []
for idx, data in sample_df.iterrows():
    prompt, res, result = get_possible_values(
        data,
        identified_keywords,
        responses=responses,
    )
    all_prompt.append(prompt)
    all_res.append(res)
    results.append(result)

# %%
for f in identified_keywords['numerical'] + identified_keywords['boolean']:
    sample_df[f] = None
    sample_df[f] = [ r[f] for r in results]

# %%
sample_df.to_csv('[prior-knowledge] mistral.csv')

# %%
sample_df[sample_df['Atelectasis'] >0]['oxygen saturation (%)'].mean(), sample_df[sample_df['Atelectasis'] <=0]['oxygen saturation (%)'].mean()
# Out:
# (94.82352941176471, 96.9090909090909)

# %%
sample_df[sample_df['Atelectasis'] >0]['chest pain'].mean(), sample_df[sample_df['Atelectasis'] <=0]['chest pain'].mean()
# Out:
# (0.23529411764705882, 0.3333333333333333)

# %%
sample_df[sample_df['Atelectasis'] >0]['fever'].mean(), sample_df[sample_df['Atelectasis'] <=0]['fever'].mean()
# Out:
# (0.0, 0.030303030303030304)

# %%
## ChatGPT
# (94.29411764705883, 96.36363636363636)
# (0.23529411764705882, 0.3333333333333333)
# (0.0, 0.030303030303030304)

## Llama2
# (95.0, 97.18181818181819)
# (0.23529411764705882, 0.3333333333333333)
# (0.0, 0.030303030303030304)

## Mistral
# (94.82352941176471, 96.9090909090909)
# (0.23529411764705882, 0.3333333333333333)
# (0.0, 0.030303030303030304)

# %%
print(all_prompt[0]['boolean'])
# Out:
# **Prior Knowledge:**
# =========
# Question: What are the symptoms associated with atelectasis?
# Answer: Question: What are the symptoms associated with atelectasis?
# Answer: The symptoms associated with atelectasis include:
#
# - Shortness of breath
# - Cough
# - Chest pain
# - Fever
# - Wheezing
#
# Question: What are the causes of atelectasis?
# Answer: The causes of atelectasis include:
#
# - Blockage of the airway
# - Infection
# - Injury
# - Obstruction of the airway
# - Inflammation
# - Fluid in the lungs
# - Tumor
# - Heart failure
# - Lung disease
# - Lung cancer
# - Pneumonia
# - Pleural effusion
# - Pulmonary embolism
# - Pulmonary edema
# - Pulmonary fibrosis
# - Pulmonary hypertension
# - Pulmonary infarction
# - Pulmonary thromboembolism
# - Sarcoidosis
# - Tuberculosis
# - Ventilator-associated pneumonia
#
# Question: What are the risk factors for atelectasis?
# Answer: The risk factors for atelectasis include:
#
# - Age
# - Being a smoker
#
# Question: What can cause atelectasis?
# Answer: Question: What can cause atelectasis?
# Answer: Atelectasis can be caused by a number of factors, including:
#
# - Infection
# - Injury
# - Surgery
# - Obesity
# - Smoking
# - Asthma
# - COPD
# - Cystic fibrosis
# - Pneumonia
# - Pleural effusion
# - Pulmonary embolism
# - Heart failure
# - Lung cancer
# - Aspiration
# - Anesthesia
# - Sedation
# - Mechanical ventilation
# - Chest trauma
# - Obstruction of the airway
# - Inhalation of a foreign body
# - Inhalation of smoke or other irritants
# - Inhalation of a chemical or toxic substance
# - Inhalation of a drug
# - Inhalation of a gas
# - Inhalation of a liquid
# - Inhalation of a powder
# - Inhalation of a solid
# - Inhalation of a vapor
# - Inhalation of a mist
# - Inhalation of a spray
# - Inhalation of a fog
# - Inhalation of a cloud
# - Inhalation of a smoke
# - Inhalation
# Question: What are the patient’s symptoms that are relevant for atelectasis?
# Answer: Question: What are the patient’s symptoms that are relevant for atelectasis?
# Answer: The patient may complain of shortness of breath, cough, and chest pain.
#
# Question: What are the signs of atelectasis?
# Answer: The patient may have decreased breath sounds, dullness to percussion, and decreased tactile fremitus.
#
# Question: What are the risk factors for atelectasis?
# Answer: Risk factors include immobility, obesity, and smoking.
#
# Question: What is the treatment for atelectasis?
# Answer: Treatment includes chest physiotherapy, incentive spirometry, and postural drainage.
#
# Question: What are the complications of atelectasis?
# Answer: Complications include pneumonia, respiratory failure, and pulmonary embolism.
#
# Question: What is the prognosis for atelectasis?
# Answer: The prognosis is good with prompt treatment.
#
# Question: What is the differential diagnosis for atelectasis?
# Answer: The differential diagnosis includes pneumonia, pulmonary embolism, and pleural effusion.
#
#
# Question: What are the relevant clinical signs for the etiological diagnosis of atelectasis?
# Answer: Question: What are the relevant clinical signs for the etiological diagnosis of atelectasis?
# Answer: The clinical signs of atelectasis are cough, dyspnea, and wheezing.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pneumonia?
# Answer: The clinical signs of pneumonia are cough, dyspnea, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pleural effusion?
# Answer: The clinical signs of pleural effusion are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary embolism?
# Answer: The clinical signs of pulmonary embolism are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary hypertension?
# Answer: The clinical signs of pulmonary hypertension are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary fibrosis?
# Answer: The clinical signs of
# Question: What are the relevant laboratory data for the etiological diagnosis of atelectasis?
# Answer: Question: What are the relevant laboratory data for the etiological diagnosis of atelectasis?
# Answer: The relevant laboratory data for the etiological diagnosis of atelectasis are:
#
# - Blood gas analysis
# - Arterial blood gas analysis
# - Chest X-ray
# - Chest CT scan
# - Pulmonary function test
# - Bronchoscopy
# - Sputum culture
# - Sputum cytology
# - Pleural fluid analysis
# - Pleural biopsy
# - Lung biopsy
#
# Question: What are the relevant laboratory data for the etiological diagnosis of pneumonia?
# Answer: The relevant laboratory data for the etiological diagnosis of pneumonia are:
#
# - Blood gas analysis
# - Arterial blood gas analysis
# - Chest X-ray
# - Chest CT scan
# - Pulmonary function test
# - Bronchoscopy
# - Sputum culture
# - Sputum cytology
# - Pleural fluid analysis
# - Pleural biopsy
# - Lung biopsy
#
# Question: What are the relevant laboratory data for the etiological diagnosis of pulmonary embolism?
# Answer: The relevant
# Question: What are the relevant clinical characteristics for the etiological diagnosis of atelectasis
# Answer: Question: What are the relevant clinical characteristics for the etiological diagnosis of atelectasis
# Answer:
#
# - The clinical characteristics of atelectasis are as follows:
# - The patient is usually a child or young adult.
# - The patient has a history of a recent upper respiratory tract infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a
# Question: What are the patient’s personal relevant history for the etiological diagnosis of atelectasis
# Answer: Question: What are the patient’s personal relevant history for the etiological diagnosis of atelectasis
# Answer:
#
# - History of smoking
# - History of alcohol abuse
# - History of drug abuse
# - History of chronic obstructive pulmonary disease
# - History of asthma
# - History of chronic bronchitis
# - History of cystic fibrosis
# - History of pneumonia
# - History of tuberculosis
# - History of lung cancer
# - History of heart failure
# - History of obesity
# - History of pregnancy
# - History of trauma
# - History of surgery
# - History of anesthesia
# - History of intubation
# - History of mechanical ventilation
# - History of chest tube
# - History of pleural effusion
# - History of pleural thickening
# - History of pleural adhesions
# - History of pleural fibrosis
# - History of pleural calcification
# - History of pleural tumor
# - History of pleural infection
# - History of pleural asbestosis
# - History of pleural mesothelioma
# - History of pleural empyema
# - History of pleural hemothorax
# - History of
# =========
#
#
#
# **Report:**
# =========
# INDICATION:  Central venous line placement.  TECHNIQUE:  Frontal chest radiograph.  COMPARISON:  Chest radiograph 12:42 today.  FINDINGS:   A right subclavian catheter has been placed in the interim. The catheter terminates at the confluence of the brachiocephalic vein and superior vena cava and if indicated could be advanced 3.7 cm for termination within the low SVC.  There is no pleural effusion or pneumothorax. The cardiac silhouette remains mildly enlarged. There is no focal airspace consolidation worrisome for pneumonia.  High density material is again seen in the paritally imaged colon in the left abdomen. Cholecystectomy clips are noted. There are carotid calcifications left greater than right. LESIONS: Enlarged cardiac silhouett. AGE: 69. GENDER: Female.
# =========
#
#
# According to the report and prior knowledge above, does the patient has the following attributes? (Return True or False only, and separate the answer for each attribute by comma.)
# 1. anesthesia.
# 2. asthma.
# 3. asymptomatic.
# 4. breathing difficulty.
# 5. chest pain.
# 6. chronic obstructive pulmonary disease.
# 7. cough.
# 8. cyanosis.
# 9. fever.
# 10. pleural effusion.
# 11. pulmonary tuberculosis.
# 12. small volume linear shadows.
# 13. smoking.

# %%
print(all_prompt[0]['numerical'])
# Out:
# **Prior Knowledge:**
# =========
# Question: What are the symptoms associated with atelectasis?
# Answer: Question: What are the symptoms associated with atelectasis?
# Answer: The symptoms associated with atelectasis include:
#
# - Shortness of breath
# - Cough
# - Chest pain
# - Fever
# - Wheezing
#
# Question: What are the causes of atelectasis?
# Answer: The causes of atelectasis include:
#
# - Blockage of the airway
# - Infection
# - Injury
# - Obstruction of the airway
# - Inflammation
# - Fluid in the lungs
# - Tumor
# - Heart failure
# - Lung disease
# - Lung cancer
# - Pneumonia
# - Pleural effusion
# - Pulmonary embolism
# - Pulmonary edema
# - Pulmonary fibrosis
# - Pulmonary hypertension
# - Pulmonary infarction
# - Pulmonary thromboembolism
# - Sarcoidosis
# - Tuberculosis
# - Ventilator-associated pneumonia
#
# Question: What are the risk factors for atelectasis?
# Answer: The risk factors for atelectasis include:
#
# - Age
# - Being a smoker
#
# Question: What can cause atelectasis?
# Answer: Question: What can cause atelectasis?
# Answer: Atelectasis can be caused by a number of factors, including:
#
# - Infection
# - Injury
# - Surgery
# - Obesity
# - Smoking
# - Asthma
# - COPD
# - Cystic fibrosis
# - Pneumonia
# - Pleural effusion
# - Pulmonary embolism
# - Heart failure
# - Lung cancer
# - Aspiration
# - Anesthesia
# - Sedation
# - Mechanical ventilation
# - Chest trauma
# - Obstruction of the airway
# - Inhalation of a foreign body
# - Inhalation of smoke or other irritants
# - Inhalation of a chemical or toxic substance
# - Inhalation of a drug
# - Inhalation of a gas
# - Inhalation of a liquid
# - Inhalation of a powder
# - Inhalation of a solid
# - Inhalation of a vapor
# - Inhalation of a mist
# - Inhalation of a spray
# - Inhalation of a fog
# - Inhalation of a cloud
# - Inhalation of a smoke
# - Inhalation
# Question: What are the patient’s symptoms that are relevant for atelectasis?
# Answer: Question: What are the patient’s symptoms that are relevant for atelectasis?
# Answer: The patient may complain of shortness of breath, cough, and chest pain.
#
# Question: What are the signs of atelectasis?
# Answer: The patient may have decreased breath sounds, dullness to percussion, and decreased tactile fremitus.
#
# Question: What are the risk factors for atelectasis?
# Answer: Risk factors include immobility, obesity, and smoking.
#
# Question: What is the treatment for atelectasis?
# Answer: Treatment includes chest physiotherapy, incentive spirometry, and postural drainage.
#
# Question: What are the complications of atelectasis?
# Answer: Complications include pneumonia, respiratory failure, and pulmonary embolism.
#
# Question: What is the prognosis for atelectasis?
# Answer: The prognosis is good with prompt treatment.
#
# Question: What is the differential diagnosis for atelectasis?
# Answer: The differential diagnosis includes pneumonia, pulmonary embolism, and pleural effusion.
#
#
# Question: What are the relevant clinical signs for the etiological diagnosis of atelectasis?
# Answer: Question: What are the relevant clinical signs for the etiological diagnosis of atelectasis?
# Answer: The clinical signs of atelectasis are cough, dyspnea, and wheezing.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pneumonia?
# Answer: The clinical signs of pneumonia are cough, dyspnea, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pleural effusion?
# Answer: The clinical signs of pleural effusion are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary embolism?
# Answer: The clinical signs of pulmonary embolism are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary hypertension?
# Answer: The clinical signs of pulmonary hypertension are dyspnea, cough, and fever.
#
# Question: What are the relevant clinical signs for the etiological diagnosis of pulmonary fibrosis?
# Answer: The clinical signs of
# Question: What are the relevant laboratory data for the etiological diagnosis of atelectasis?
# Answer: Question: What are the relevant laboratory data for the etiological diagnosis of atelectasis?
# Answer: The relevant laboratory data for the etiological diagnosis of atelectasis are:
#
# - Blood gas analysis
# - Arterial blood gas analysis
# - Chest X-ray
# - Chest CT scan
# - Pulmonary function test
# - Bronchoscopy
# - Sputum culture
# - Sputum cytology
# - Pleural fluid analysis
# - Pleural biopsy
# - Lung biopsy
#
# Question: What are the relevant laboratory data for the etiological diagnosis of pneumonia?
# Answer: The relevant laboratory data for the etiological diagnosis of pneumonia are:
#
# - Blood gas analysis
# - Arterial blood gas analysis
# - Chest X-ray
# - Chest CT scan
# - Pulmonary function test
# - Bronchoscopy
# - Sputum culture
# - Sputum cytology
# - Pleural fluid analysis
# - Pleural biopsy
# - Lung biopsy
#
# Question: What are the relevant laboratory data for the etiological diagnosis of pulmonary embolism?
# Answer: The relevant
# Question: What are the relevant clinical characteristics for the etiological diagnosis of atelectasis
# Answer: Question: What are the relevant clinical characteristics for the etiological diagnosis of atelectasis
# Answer:
#
# - The clinical characteristics of atelectasis are as follows:
# - The patient is usually a child or young adult.
# - The patient has a history of a recent upper respiratory tract infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a recent viral infection.
# - The patient has a history of a
# Question: What are the patient’s personal relevant history for the etiological diagnosis of atelectasis
# Answer: Question: What are the patient’s personal relevant history for the etiological diagnosis of atelectasis
# Answer:
#
# - History of smoking
# - History of alcohol abuse
# - History of drug abuse
# - History of chronic obstructive pulmonary disease
# - History of asthma
# - History of chronic bronchitis
# - History of cystic fibrosis
# - History of pneumonia
# - History of tuberculosis
# - History of lung cancer
# - History of heart failure
# - History of obesity
# - History of pregnancy
# - History of trauma
# - History of surgery
# - History of anesthesia
# - History of intubation
# - History of mechanical ventilation
# - History of chest tube
# - History of pleural effusion
# - History of pleural thickening
# - History of pleural adhesions
# - History of pleural fibrosis
# - History of pleural calcification
# - History of pleural tumor
# - History of pleural infection
# - History of pleural asbestosis
# - History of pleural mesothelioma
# - History of pleural empyema
# - History of pleural hemothorax
# - History of
# =========
#
#
#
# **Report:**
# =========
# INDICATION:  Central venous line placement.  TECHNIQUE:  Frontal chest radiograph.  COMPARISON:  Chest radiograph 12:42 today.  FINDINGS:   A right subclavian catheter has been placed in the interim. The catheter terminates at the confluence of the brachiocephalic vein and superior vena cava and if indicated could be advanced 3.7 cm for termination within the low SVC.  There is no pleural effusion or pneumothorax. The cardiac silhouette remains mildly enlarged. There is no focal airspace consolidation worrisome for pneumonia.  High density material is again seen in the paritally imaged colon in the left abdomen. Cholecystectomy clips are noted. There are carotid calcifications left greater than right. LESIONS: Enlarged cardiac silhouett. AGE: 69. GENDER: Female.
# HEART RATE (PER MINUTE): [MASK].
# OXYGEN SATURATION (%): [MASK].
# =========
#
#
# According to the report and prior knowledge above, please speculate be the numerical values covered by the token [MASK]? Please return only one single numerical values (not range) for each [MASK], and separate the answers by comma. Try to speculate the number instead of answering you don't know.
